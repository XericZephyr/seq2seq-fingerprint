# %%
import os
import sys
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), "../")))
import tensorflow as tf

# %%
from unsupervised.seq2seq_model import FingerprintFetcher

# %%
model_dir = "/home/xiaoyu/expr/test/gru-2-128"
vocab_path = "/home/xiaoyu/expr/seq2seq-fp/pretrain/pm2.vocab"

# %%
tf.reset_default_graph()
with tf.Session() as sess:
    fetcher = FingerprintFetcher(model_dir, vocab_path, sess)
# Out:
# Loading seq2seq model definition from /home/xiaoyu/expr/test/gru-2-128/model.json...
# /home/xiaoyu/anaconda2/lib/python2.7/site-packages/h5py/__init__.py:34: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# model_with_buckets/embedding_attention_seq2seq/rnn/rnn/embedding_wrapper/embedding_wrapper/multi_rnn_cell/cell_0/cell_0/gru_cell/add_1
# model_with_buckets/embedding_attention_seq2seq/rnn/rnn/embedding_wrapper/embedding_wrapper/multi_rnn_cell/cell_1/cell_1/gru_cell/add_1
# model_with_buckets/embedding_attention_seq2seq/rnn/rnn/embedding_wrapper/embedding_wrapper/multi_rnn_cell/cell_0/cell_0/gru_cell/add_2
# model_with_buckets/embedding_attention_seq2seq/rnn/rnn/embedding_wrapper/embedding_wrapper/multi_rnn_cell/cell_1/cell_1/gru_cell/add_2
# ...
